# %% [markdown]
# [![image](https://jupyterlite.rtfd.io/en/latest/_static/badge.svg)](https://demo.leafmap.org/lab/index.html?path=workshops/ICRW_2023.ipynb)
# [![image](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/opengeos/leafmap/blob/master/docs/workshops/ICRW_2023.ipynb)
#
# **An Introduction to Watershed Analysis with Leafmap and WhiteboxTools**
#
# This [notebook](https://leafmap.org/workshops/ICRW_2023) provides an introduction to watershed analysis with Leafmap and WhiteboxTools. It is designed for The Interagency Conference on Research in the Watersheds ([ICRW](https://icrwatersheds.org/)) 2023 workshop - [Working with Geospatial Hydrologic Data for Watershed Analyses in R and Python Using Web Services](https://icrwatersheds.org/icrw8/icrw8-schedule/june-5-workshops/).
#
# - Leafmap: <https://leafmap.org>
# - WhiteboxTools: <https://www.whiteboxgeo.com>
# - WhiteboxTools User Manual: <https://www.whiteboxgeo.com/manual/wbt_book>

# %% [markdown]
# ## Installation
#
# Uncomment and run the following cell to install necessary packages for this notebook, including leafmap, geopandas, localtileserver, rio-cogeo, pynhd, py3dep.

# %%
# %pip install leafmap[raster] geopandas
# Out:
# Requirement already satisfied: geopandas in /usr/local/lib/python3.12/dist-packages (1.1.3)
# Requirement already satisfied: leafmap[raster] in /usr/local/lib/python3.12/dist-packages (0.62.0)
# Requirement already satisfied: anywidget in /usr/local/lib/python3.12/dist-packages (from leafmap[raster]) (0.9.21)
# Requirement already satisfied: bqplot in /usr/local/lib/python3.12/dist-packages (from leafmap[raster]) (0.12.47)
# Requirement already satisfied: duckdb>=1.4.1 in /usr/local/lib/python3.12/dist-packages (from leafmap[raster]) (1.5.4)
# Requirement already satisfied: folium in /usr/local/lib/python3.12/dist-packages (from leafmap[raster]) (0.20.0)
# Requirement already satisfied: gdown in /usr/local/lib/python3.12/dist-packages (from leafmap[raster]) (5.2.2)
# Requirement already satisfied: geojson in /usr/local/lib/python3.12/dist-packages (from leafmap[raster]) (3.3.0)
# Requirement already satisfied: ipyevents in /usr/local/lib/python3.12/dist-packages (from leafmap[raster]) (2.0.4)
# Requirement already satisfied: ipyfilechooser in /usr/local/lib/python3.12/dist-packages (from leafmap[raster]) (0.6.0)
# Requirement already satisfied: ipyleaflet in /usr/local/lib/python3.12/dist-packages (from leafmap[raster]) (0.20.0)
# Requirement already satisfied: ipyvue>=1.12.0 in /usr/local/lib/python3.12/dist-packages (from leafmap[raster]) (1.12.0)
# Requirement already satisfied: ipyvuetify in /usr/local/lib/python3.12/dist-packages (from leafmap[raster]) (1.11.3)
# Requirement already satisfied: ipywidgets in /usr/local/lib/python3.12/dist-packages (from leafmap[raster]) (7.7.1)
# Requirement already satisfied: maplibre in /usr/local/lib/python3.12/dist-packages (from leafmap[raster]) (0.3.6)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from leafmap[raster]) (3.10.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from leafmap[raster]) (2.0.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from leafmap[raster]) (2.2.2)
# Requirement already satisfied: plotly in /usr/local/lib/python3.12/dist-packages (from leafmap[raster]) (5.24.1)
# Requirement already satisfied: pystac-client in /usr/local/lib/python3.12/dist-packages (from leafmap[raster]) (0.9.0)
# Requirement already satisfied: python-box in /usr/local/lib/python3.12/dist-packages (from leafmap[raster]) (7.4.1)
# Requirement already satisfied: scooby in /usr/local/lib/python3.12/dist-packages (from leafmap[raster]) (0.11.2)
# Requirement already satisfied: whiteboxgui in /usr/local/lib/python3.12/dist-packages (from leafmap[raster]) (2.3.0)
# Requirement already satisfied: xyzservices in /usr/local/lib/python3.12/dist-packages (from leafmap[raster]) (2026.3.0)
# Requirement already satisfied: localtileserver>=0.10.6 in /usr/local/lib/python3.12/dist-packages (from leafmap[raster]) (1.0.0)
# Requirement already satisfied: jupyter-server-proxy in /usr/local/lib/python3.12/dist-packages (from leafmap[raster]) (4.5.0)
# Requirement already satisfied: rio-cogeo in /usr/local/lib/python3.12/dist-packages (from leafmap[raster]) (5.4.2)
# Requirement already satisfied: rioxarray in /usr/local/lib/python3.12/dist-packages (from leafmap[raster]) (0.22.0)
# Requirement already satisfied: netcdf4 in /usr/local/lib/python3.12/dist-packages (from leafmap[raster]) (1.7.4)
# Requirement already satisfied: d2spy in /usr/local/lib/python3.12/dist-packages (from leafmap[raster]) (0.4.3)
# Requirement already satisfied: h5netcdf in /usr/local/lib/python3.12/dist-packages (from leafmap[raster]) (1.8.1)
# Requirement already satisfied: h5py in /usr/local/lib/python3.12/dist-packages (from leafmap[raster]) (3.16.0)
# Requirement already satisfied: opera-utils in /usr/local/lib/python3.12/dist-packages (from leafmap[raster]) (0.25.8)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from leafmap[raster]) (5.9.5)
# Requirement already satisfied: titiler in /usr/local/lib/python3.12/dist-packages (from leafmap[raster]) (0.25.0)
# Requirement already satisfied: uvicorn in /usr/local/lib/python3.12/dist-packages (from leafmap[raster]) (0.49.0)
# Requirement already satisfied: pyogrio>=0.7.2 in /usr/local/lib/python3.12/dist-packages (from geopandas) (0.12.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from geopandas) (26.2)
# Requirement already satisfied: pyproj>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from geopandas) (3.7.2)
# Requirement already satisfied: shapely>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from geopandas) (2.1.2)
# Requirement already satisfied: ipykernel>=4.5.1 in /usr/local/lib/python3.12/dist-packages (from ipywidgets->leafmap[raster]) (6.17.1)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /usr/local/lib/python3.12/dist-packages (from ipywidgets->leafmap[raster]) (0.2.0)
# Requirement already satisfied: traitlets>=4.3.1 in /usr/local/lib/python3.12/dist-packages (from ipywidgets->leafmap[raster]) (5.7.1)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.12/dist-packages (from ipywidgets->leafmap[raster]) (3.6.10)
# Requirement already satisfied: ipython>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from ipywidgets->leafmap[raster]) (7.34.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from ipywidgets->leafmap[raster]) (3.0.16)
# Requirement already satisfied: click in /usr/local/lib/python3.12/dist-packages (from localtileserver>=0.10.6->leafmap[raster]) (8.4.1)
# Requirement already satisfied: fastapi>=0.100.0 in /usr/local/lib/python3.12/dist-packages (from localtileserver>=0.10.6->leafmap[raster]) (0.136.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from localtileserver>=0.10.6->leafmap[raster]) (3.1.6)
# Requirement already satisfied: jupyter-loopback>=0.3.3 in /usr/local/lib/python3.12/dist-packages (from jupyter-loopback[comm]>=0.3.3->localtileserver>=0.10.6->leafmap[raster]) (0.3.3)
# Requirement already satisfied: rio-tiler in /usr/local/lib/python3.12/dist-packages (from localtileserver>=0.10.6->leafmap[raster]) (7.9.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from localtileserver>=0.10.6->leafmap[raster]) (2.32.4)
# Requirement already satisfied: server-thread in /usr/local/lib/python3.12/dist-packages (from localtileserver>=0.10.6->leafmap[raster]) (0.3.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->leafmap[raster]) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->leafmap[raster]) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->leafmap[raster]) (2026.2)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from pyogrio>=0.7.2->geopandas) (2026.5.20)
# Requirement already satisfied: psygnal>=0.8.1 in /usr/local/lib/python3.12/dist-packages (from anywidget->leafmap[raster]) (0.15.1)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.12/dist-packages (from anywidget->leafmap[raster]) (4.15.0)
# Requirement already satisfied: traittypes>=0.0.6 in /usr/local/lib/python3.12/dist-packages (from bqplot->leafmap[raster]) (0.2.3)
# Requirement already satisfied: branca>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from folium->leafmap[raster]) (0.8.2)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.12/dist-packages (from gdown->leafmap[raster]) (4.13.5)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from gdown->leafmap[raster]) (3.29.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from gdown->leafmap[raster]) (4.67.3)
# Requirement already satisfied: jupyter-leaflet<0.21,>=0.20 in /usr/local/lib/python3.12/dist-packages (from ipyleaflet->leafmap[raster]) (0.20.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.12/dist-packages (from jupyter-server-proxy->leafmap[raster]) (3.14.1)
# Requirement already satisfied: jupyter-server>=1.24.0 in /usr/local/lib/python3.12/dist-packages (from jupyter-server-proxy->leafmap[raster]) (2.18.2)
# Requirement already satisfied: simpervisor>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from jupyter-server-proxy->leafmap[raster]) (1.0.0)
# Requirement already satisfied: tornado>=6.1.0 in /usr/local/lib/python3.12/dist-packages (from jupyter-server-proxy->leafmap[raster]) (6.5.7)
# Requirement already satisfied: eval-type-backport in /usr/local/lib/python3.12/dist-packages (from maplibre->leafmap[raster]) (0.4.0)
# Requirement already satisfied: pydantic>=2.5.3 in /usr/local/lib/python3.12/dist-packages (from maplibre->leafmap[raster]) (2.12.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->leafmap[raster]) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->leafmap[raster]) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->leafmap[raster]) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->leafmap[raster]) (1.5.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->leafmap[raster]) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->leafmap[raster]) (3.3.2)
# Requirement already satisfied: cftime in /usr/local/lib/python3.12/dist-packages (from netcdf4->leafmap[raster]) (1.6.5)
# Requirement already satisfied: pooch>=1.7 in /usr/local/lib/python3.12/dist-packages (from opera-utils->leafmap[raster]) (1.9.0)
# Requirement already satisfied: s3fs in /usr/local/lib/python3.12/dist-packages (from opera-utils->leafmap[raster]) (2026.6.0)
# Requirement already satisfied: tyro>=0.9 in /usr/local/lib/python3.12/dist-packages (from opera-utils->leafmap[raster]) (1.0.13)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.12/dist-packages (from plotly->leafmap[raster]) (9.1.4)
# Requirement already satisfied: pystac>=1.10.0 in /usr/local/lib/python3.12/dist-packages (from pystac[validation]>=1.10.0->pystac-client->leafmap[raster]) (1.14.3)
# Requirement already satisfied: rasterio>=1.3.3 in /usr/local/lib/python3.12/dist-packages (from rio-cogeo->leafmap[raster]) (1.5.0)
# Requirement already satisfied: morecantile<7.0,>=5.0 in /usr/local/lib/python3.12/dist-packages (from rio-cogeo->leafmap[raster]) (6.2.0)
# Requirement already satisfied: xarray>=2026.2 in /usr/local/lib/python3.12/dist-packages (from rioxarray->leafmap[raster]) (2026.4.0)
# Requirement already satisfied: titiler-application==0.25.0 in /usr/local/lib/python3.12/dist-packages (from titiler->leafmap[raster]) (0.25.0)
# Requirement already satisfied: titiler-core==0.25.0 in /usr/local/lib/python3.12/dist-packages (from titiler->leafmap[raster]) (0.25.0)
# Requirement already satisfied: titiler-extensions==0.25.0 in /usr/local/lib/python3.12/dist-packages (from titiler->leafmap[raster]) (0.25.0)
# Requirement already satisfied: titiler-mosaic==0.25.0 in /usr/local/lib/python3.12/dist-packages (from titiler->leafmap[raster]) (0.25.0)
# Requirement already satisfied: titiler-xarray==0.25.0 in /usr/local/lib/python3.12/dist-packages (from titiler->leafmap[raster]) (0.25.0)
# Requirement already satisfied: pydantic-settings~=2.0 in /usr/local/lib/python3.12/dist-packages (from titiler-application==0.25.0->titiler->leafmap[raster]) (2.14.1)
# Requirement already satisfied: starlette-cramjam<0.6,>=0.4 in /usr/local/lib/python3.12/dist-packages (from titiler-application==0.25.0->titiler->leafmap[raster]) (0.5.1)
# Requirement already satisfied: geojson-pydantic<3.0,>=1.1.2 in /usr/local/lib/python3.12/dist-packages (from titiler-core==0.25.0->titiler->leafmap[raster]) (2.1.1)
# Requirement already satisfied: simplejson in /usr/local/lib/python3.12/dist-packages (from titiler-core==0.25.0->titiler->leafmap[raster]) (4.1.1)
# Requirement already satisfied: cogeo-mosaic<9.0,>=8.0 in /usr/local/lib/python3.12/dist-packages (from titiler-mosaic==0.25.0->titiler->leafmap[raster]) (8.2.0)
# Requirement already satisfied: obstore in /usr/local/lib/python3.12/dist-packages (from titiler-xarray==0.25.0->titiler->leafmap[raster]) (0.10.1)
# Requirement already satisfied: zarr<4.0,>=3.1 in /usr/local/lib/python3.12/dist-packages (from titiler-xarray==0.25.0->titiler->leafmap[raster]) (3.2.1)
# Requirement already satisfied: opentelemetry-api in /usr/local/lib/python3.12/dist-packages (from titiler-core[telemetry]==0.25.0->titiler-application==0.25.0->titiler->leafmap[raster]) (1.42.1)
# Requirement already satisfied: opentelemetry-exporter-otlp in /usr/local/lib/python3.12/dist-packages (from titiler-core[telemetry]==0.25.0->titiler-application==0.25.0->titiler->leafmap[raster]) (1.42.1)
# Requirement already satisfied: opentelemetry-instrumentation-fastapi in /usr/local/lib/python3.12/dist-packages (from titiler-core[telemetry]==0.25.0->titiler-application==0.25.0->titiler->leafmap[raster]) (0.63b1)
# Requirement already satisfied: opentelemetry-instrumentation-logging in /usr/local/lib/python3.12/dist-packages (from titiler-core[telemetry]==0.25.0->titiler-application==0.25.0->titiler->leafmap[raster]) (0.63b1)
# Requirement already satisfied: opentelemetry-sdk in /usr/local/lib/python3.12/dist-packages (from titiler-core[telemetry]==0.25.0->titiler-application==0.25.0->titiler->leafmap[raster]) (1.42.1)
# Requirement already satisfied: rio-stac<0.13,>=0.12 in /usr/local/lib/python3.12/dist-packages (from titiler-extensions[cogeo,stac]==0.25.0->titiler-application==0.25.0->titiler->leafmap[raster]) (0.12.0)
# Requirement already satisfied: h11>=0.8 in /usr/local/lib/python3.12/dist-packages (from uvicorn->leafmap[raster]) (0.16.0)
# Requirement already satisfied: ipytree in /usr/local/lib/python3.12/dist-packages (from whiteboxgui->leafmap[raster]) (0.2.2)
# Requirement already satisfied: whitebox in /usr/local/lib/python3.12/dist-packages (from whiteboxgui->leafmap[raster]) (2.3.6)
# Requirement already satisfied: starlette>=0.46.0 in /usr/local/lib/python3.12/dist-packages (from fastapi>=0.100.0->localtileserver>=0.10.6->leafmap[raster]) (0.52.1)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from fastapi>=0.100.0->localtileserver>=0.10.6->leafmap[raster]) (0.4.2)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from fastapi>=0.100.0->localtileserver>=0.10.6->leafmap[raster]) (0.0.4)
# Requirement already satisfied: debugpy>=1.0 in /usr/local/lib/python3.12/dist-packages (from ipykernel>=4.5.1->ipywidgets->leafmap[raster]) (1.8.15)
# Requirement already satisfied: jupyter-client>=6.1.12 in /usr/local/lib/python3.12/dist-packages (from ipykernel>=4.5.1->ipywidgets->leafmap[raster]) (7.4.9)
# Requirement already satisfied: matplotlib-inline>=0.1 in /usr/local/lib/python3.12/dist-packages (from ipykernel>=4.5.1->ipywidgets->leafmap[raster]) (0.2.2)
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.12/dist-packages (from ipykernel>=4.5.1->ipywidgets->leafmap[raster]) (1.6.0)
# Requirement already satisfied: pyzmq>=17 in /usr/local/lib/python3.12/dist-packages (from ipykernel>=4.5.1->ipywidgets->leafmap[raster]) (26.2.1)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.12/dist-packages (from ipython>=4.0.0->ipywidgets->leafmap[raster]) (75.2.0)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.12/dist-packages (from ipython>=4.0.0->ipywidgets->leafmap[raster]) (0.20.0)
# Requirement already satisfied: decorator in /usr/local/lib/python3.12/dist-packages (from ipython>=4.0.0->ipywidgets->leafmap[raster]) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.12/dist-packages (from ipython>=4.0.0->ipywidgets->leafmap[raster]) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from ipython>=4.0.0->ipywidgets->leafmap[raster]) (3.0.52)
# Requirement already satisfied: pygments in /usr/local/lib/python3.12/dist-packages (from ipython>=4.0.0->ipywidgets->leafmap[raster]) (2.20.0)
# Requirement already satisfied: backcall in /usr/local/lib/python3.12/dist-packages (from ipython>=4.0.0->ipywidgets->leafmap[raster]) (0.2.0)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.12/dist-packages (from ipython>=4.0.0->ipywidgets->leafmap[raster]) (4.9.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->localtileserver>=0.10.6->leafmap[raster]) (3.0.3)
# Requirement already satisfied: anyio>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from jupyter-server>=1.24.0->jupyter-server-proxy->leafmap[raster]) (4.13.0)
# Requirement already satisfied: argon2-cffi>=21.1 in /usr/local/lib/python3.12/dist-packages (from jupyter-server>=1.24.0->jupyter-server-proxy->leafmap[raster]) (25.1.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /usr/local/lib/python3.12/dist-packages (from jupyter-server>=1.24.0->jupyter-server-proxy->leafmap[raster]) (5.9.1)
# Requirement already satisfied: jupyter-events>=0.11.0 in /usr/local/lib/python3.12/dist-packages (from jupyter-server>=1.24.0->jupyter-server-proxy->leafmap[raster]) (0.12.1)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in /usr/local/lib/python3.12/dist-packages (from jupyter-server>=1.24.0->jupyter-server-proxy->leafmap[raster]) (0.5.4)
# Requirement already satisfied: nbconvert>=6.4.4 in /usr/local/lib/python3.12/dist-packages (from jupyter-server>=1.24.0->jupyter-server-proxy->leafmap[raster]) (7.17.1)
# Requirement already satisfied: nbformat>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from jupyter-server>=1.24.0->jupyter-server-proxy->leafmap[raster]) (5.10.4)
# Requirement already satisfied: prometheus-client>=0.9 in /usr/local/lib/python3.12/dist-packages (from jupyter-server>=1.24.0->jupyter-server-proxy->leafmap[raster]) (0.25.0)
# Requirement already satisfied: send2trash>=1.8.2 in /usr/local/lib/python3.12/dist-packages (from jupyter-server>=1.24.0->jupyter-server-proxy->leafmap[raster]) (2.1.0)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.12/dist-packages (from jupyter-server>=1.24.0->jupyter-server-proxy->leafmap[raster]) (0.18.1)
# Requirement already satisfied: websocket-client>=1.7 in /usr/local/lib/python3.12/dist-packages (from jupyter-server>=1.24.0->jupyter-server-proxy->leafmap[raster]) (1.9.0)
# Requirement already satisfied: attrs in /usr/local/lib/python3.12/dist-packages (from morecantile<7.0,>=5.0->rio-cogeo->leafmap[raster]) (26.1.0)
# Requirement already satisfied: platformdirs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from pooch>=1.7->opera-utils->leafmap[raster]) (4.10.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.5.3->maplibre->leafmap[raster]) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.5.3->maplibre->leafmap[raster]) (2.41.4)
# Requirement already satisfied: jsonschema~=4.18 in /usr/local/lib/python3.12/dist-packages (from pystac[validation]>=1.10.0->pystac-client->leafmap[raster]) (4.26.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas->leafmap[raster]) (1.17.0)
# Requirement already satisfied: affine in /usr/local/lib/python3.12/dist-packages (from rasterio>=1.3.3->rio-cogeo->leafmap[raster]) (2.4.0)
# Requirement already satisfied: cligj>=0.5 in /usr/local/lib/python3.12/dist-packages (from rasterio>=1.3.3->rio-cogeo->leafmap[raster]) (0.7.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->localtileserver>=0.10.6->leafmap[raster]) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->localtileserver>=0.10.6->leafmap[raster]) (3.18)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->localtileserver>=0.10.6->leafmap[raster]) (2.5.0)
# Requirement already satisfied: cachetools in /usr/local/lib/python3.12/dist-packages (from rio-tiler->localtileserver>=0.10.6->leafmap[raster]) (6.2.6)
# Requirement already satisfied: color-operations in /usr/local/lib/python3.12/dist-packages (from rio-tiler->localtileserver>=0.10.6->leafmap[raster]) (0.2.0)
# Requirement already satisfied: httpx in /usr/local/lib/python3.12/dist-packages (from rio-tiler->localtileserver>=0.10.6->leafmap[raster]) (0.28.1)
# Requirement already satisfied: numexpr in /usr/local/lib/python3.12/dist-packages (from rio-tiler->localtileserver>=0.10.6->leafmap[raster]) (2.14.1)
# Requirement already satisfied: docstring-parser>=0.15 in /usr/local/lib/python3.12/dist-packages (from tyro>=0.9->opera-utils->leafmap[raster]) (0.18.0)
# Requirement already satisfied: typeguard>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from tyro>=0.9->opera-utils->leafmap[raster]) (4.5.2)
# Requirement already satisfied: notebook>=4.4.1 in /usr/local/lib/python3.12/dist-packages (from widgetsnbextension~=3.6.0->ipywidgets->leafmap[raster]) (6.5.7)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->jupyter-server-proxy->leafmap[raster]) (2.6.2)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->jupyter-server-proxy->leafmap[raster]) (1.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp->jupyter-server-proxy->leafmap[raster]) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp->jupyter-server-proxy->leafmap[raster]) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->jupyter-server-proxy->leafmap[raster]) (0.5.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->jupyter-server-proxy->leafmap[raster]) (1.24.2)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4->gdown->leafmap[raster]) (2.8.4)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown->leafmap[raster]) (1.7.1)
# Requirement already satisfied: aiobotocore<4.0.0,>=2.19.0 in /usr/local/lib/python3.12/dist-packages (from s3fs->opera-utils->leafmap[raster]) (3.7.0)
# Requirement already satisfied: fsspec<2026.6.1,>=2026.6.0 in /usr/local/lib/python3.12/dist-packages (from s3fs->opera-utils->leafmap[raster]) (2026.6.0)
# Requirement already satisfied: werkzeug in /usr/local/lib/python3.12/dist-packages (from server-thread->localtileserver>=0.10.6->leafmap[raster]) (3.1.8)
# Requirement already satisfied: httptools>=0.8.0 in /usr/local/lib/python3.12/dist-packages (from uvicorn[standard]->localtileserver>=0.10.6->leafmap[raster]) (0.8.0)
# Requirement already satisfied: python-dotenv>=0.13 in /usr/local/lib/python3.12/dist-packages (from uvicorn[standard]->localtileserver>=0.10.6->leafmap[raster]) (1.2.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from uvicorn[standard]->localtileserver>=0.10.6->leafmap[raster]) (6.0.3)
# Requirement already satisfied: uvloop>=0.15.1 in /usr/local/lib/python3.12/dist-packages (from uvicorn[standard]->localtileserver>=0.10.6->leafmap[raster]) (0.22.1)
# Requirement already satisfied: watchfiles>=0.20 in /usr/local/lib/python3.12/dist-packages (from uvicorn[standard]->localtileserver>=0.10.6->leafmap[raster]) (1.2.0)
# Requirement already satisfied: websockets>=10.4 in /usr/local/lib/python3.12/dist-packages (from uvicorn[standard]->localtileserver>=0.10.6->leafmap[raster]) (15.0.1)
# Requirement already satisfied: aioitertools<1.0.0,>=0.5.1 in /usr/local/lib/python3.12/dist-packages (from aiobotocore<4.0.0,>=2.19.0->s3fs->opera-utils->leafmap[raster]) (0.13.0)
# Requirement already satisfied: botocore<1.43.1,>=1.42.90 in /usr/local/lib/python3.12/dist-packages (from aiobotocore<4.0.0,>=2.19.0->s3fs->opera-utils->leafmap[raster]) (1.43.0)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /usr/local/lib/python3.12/dist-packages (from aiobotocore<4.0.0,>=2.19.0->s3fs->opera-utils->leafmap[raster]) (1.1.0)
# Requirement already satisfied: wrapt<3.0.0,>=1.10.10 in /usr/local/lib/python3.12/dist-packages (from aiobotocore<4.0.0,>=2.19.0->s3fs->opera-utils->leafmap[raster]) (2.2.1)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.12/dist-packages (from argon2-cffi>=21.1->jupyter-server>=1.24.0->jupyter-server-proxy->leafmap[raster]) (25.1.0)
# Requirement already satisfied: click-plugins in /usr/local/lib/python3.12/dist-packages (from cogeo-mosaic<9.0,>=8.0->titiler-mosaic==0.25.0->titiler->leafmap[raster]) (1.1.1.2)
# Requirement already satisfied: supermorecado in /usr/local/lib/python3.12/dist-packages (from cogeo-mosaic<9.0,>=8.0->titiler-mosaic==0.25.0->titiler->leafmap[raster]) (0.2.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.6 in /usr/local/lib/python3.12/dist-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets->leafmap[raster]) (0.8.7)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.12/dist-packages (from jsonschema~=4.18->pystac[validation]>=1.10.0->pystac-client->leafmap[raster]) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.12/dist-packages (from jsonschema~=4.18->pystac[validation]>=1.10.0->pystac-client->leafmap[raster]) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema~=4.18->pystac[validation]>=1.10.0->pystac-client->leafmap[raster]) (2026.5.1)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.12/dist-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets->leafmap[raster]) (0.4)
# Requirement already satisfied: python-json-logger>=2.0.4 in /usr/local/lib/python3.12/dist-packages (from jupyter-events>=0.11.0->jupyter-server>=1.24.0->jupyter-server-proxy->leafmap[raster]) (4.1.0)
# Requirement already satisfied: rfc3339-validator in /usr/local/lib/python3.12/dist-packages (from jupyter-events>=0.11.0->jupyter-server>=1.24.0->jupyter-server-proxy->leafmap[raster]) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /usr/local/lib/python3.12/dist-packages (from jupyter-events>=0.11.0->jupyter-server>=1.24.0->jupyter-server-proxy->leafmap[raster]) (0.1.1)
# Requirement already satisfied: bleach!=5.0.0 in /usr/local/lib/python3.12/dist-packages (from bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server>=1.24.0->jupyter-server-proxy->leafmap[raster]) (6.4.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.12/dist-packages (from nbconvert>=6.4.4->jupyter-server>=1.24.0->jupyter-server-proxy->leafmap[raster]) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.12/dist-packages (from nbconvert>=6.4.4->jupyter-server>=1.24.0->jupyter-server-proxy->leafmap[raster]) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in /usr/local/lib/python3.12/dist-packages (from nbconvert>=6.4.4->jupyter-server>=1.24.0->jupyter-server-proxy->leafmap[raster]) (3.2.1)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.12/dist-packages (from nbconvert>=6.4.4->jupyter-server>=1.24.0->jupyter-server-proxy->leafmap[raster]) (0.10.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.12/dist-packages (from nbconvert>=6.4.4->jupyter-server>=1.24.0->jupyter-server-proxy->leafmap[raster]) (1.5.1)
# Requirement already satisfied: fastjsonschema>=2.15 in /usr/local/lib/python3.12/dist-packages (from nbformat>=5.3.0->jupyter-server>=1.24.0->jupyter-server-proxy->leafmap[raster]) (2.21.2)
# Requirement already satisfied: nbclassic>=0.4.7 in /usr/local/lib/python3.12/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->leafmap[raster]) (1.3.3)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.12/dist-packages (from pexpect>4.3->ipython>=4.0.0->ipywidgets->leafmap[raster]) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.12/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets->leafmap[raster]) (0.8.1)
# Requirement already satisfied: cramjam<2.12,>=2.4 in /usr/local/lib/python3.12/dist-packages (from starlette-cramjam<0.6,>=0.4->titiler-application==0.25.0->titiler->leafmap[raster]) (2.11.0)
# Requirement already satisfied: donfig>=0.8 in /usr/local/lib/python3.12/dist-packages (from zarr<4.0,>=3.1->titiler-xarray==0.25.0->titiler->leafmap[raster]) (0.8.1.post1)
# Requirement already satisfied: google-crc32c>=1.5 in /usr/local/lib/python3.12/dist-packages (from zarr<4.0,>=3.1->titiler-xarray==0.25.0->titiler->leafmap[raster]) (1.8.0)
# Requirement already satisfied: numcodecs>=0.14 in /usr/local/lib/python3.12/dist-packages (from zarr<4.0,>=3.1->titiler-xarray==0.25.0->titiler->leafmap[raster]) (0.16.5)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx->rio-tiler->localtileserver>=0.10.6->leafmap[raster]) (1.0.9)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.12/dist-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server>=1.24.0->jupyter-server-proxy->leafmap[raster]) (0.5.1)
# Requirement already satisfied: tinycss2>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server>=1.24.0->jupyter-server-proxy->leafmap[raster]) (1.5.1)
# Requirement already satisfied: fqdn in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server>=1.24.0->jupyter-server-proxy->leafmap[raster]) (1.5.1)
# Requirement already satisfied: isoduration in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server>=1.24.0->jupyter-server-proxy->leafmap[raster]) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server>=1.24.0->jupyter-server-proxy->leafmap[raster]) (3.1.1)
# Requirement already satisfied: rfc3987-syntax>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server>=1.24.0->jupyter-server-proxy->leafmap[raster]) (1.1.0)
# Requirement already satisfied: uri-template in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server>=1.24.0->jupyter-server-proxy->leafmap[raster]) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server>=1.24.0->jupyter-server-proxy->leafmap[raster]) (25.10.0)
# Requirement already satisfied: notebook-shim>=0.2.3 in /usr/local/lib/python3.12/dist-packages (from nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->leafmap[raster]) (0.2.4)
# Requirement already satisfied: cffi>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server>=1.24.0->jupyter-server-proxy->leafmap[raster]) (2.0.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc==1.42.1 in /usr/local/lib/python3.12/dist-packages (from opentelemetry-exporter-otlp->titiler-core[telemetry]==0.25.0->titiler-application==0.25.0->titiler->leafmap[raster]) (1.42.1)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-http==1.42.1 in /usr/local/lib/python3.12/dist-packages (from opentelemetry-exporter-otlp->titiler-core[telemetry]==0.25.0->titiler-application==0.25.0->titiler->leafmap[raster]) (1.42.1)
# Requirement already satisfied: googleapis-common-protos~=1.57 in /usr/local/lib/python3.12/dist-packages (from opentelemetry-exporter-otlp-proto-grpc==1.42.1->opentelemetry-exporter-otlp->titiler-core[telemetry]==0.25.0->titiler-application==0.25.0->titiler->leafmap[raster]) (1.75.0)
# Requirement already satisfied: grpcio<2.0.0,>=1.63.2 in /usr/local/lib/python3.12/dist-packages (from opentelemetry-exporter-otlp-proto-grpc==1.42.1->opentelemetry-exporter-otlp->titiler-core[telemetry]==0.25.0->titiler-application==0.25.0->titiler->leafmap[raster]) (1.81.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.42.1 in /usr/local/lib/python3.12/dist-packages (from opentelemetry-exporter-otlp-proto-grpc==1.42.1->opentelemetry-exporter-otlp->titiler-core[telemetry]==0.25.0->titiler-application==0.25.0->titiler->leafmap[raster]) (1.42.1)
# Requirement already satisfied: opentelemetry-proto==1.42.1 in /usr/local/lib/python3.12/dist-packages (from opentelemetry-exporter-otlp-proto-grpc==1.42.1->opentelemetry-exporter-otlp->titiler-core[telemetry]==0.25.0->titiler-application==0.25.0->titiler->leafmap[raster]) (1.42.1)
# Requirement already satisfied: protobuf<7.0,>=5.0 in /usr/local/lib/python3.12/dist-packages (from opentelemetry-proto==1.42.1->opentelemetry-exporter-otlp-proto-grpc==1.42.1->opentelemetry-exporter-otlp->titiler-core[telemetry]==0.25.0->titiler-application==0.25.0->titiler->leafmap[raster]) (5.29.6)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.63b1 in /usr/local/lib/python3.12/dist-packages (from opentelemetry-sdk->titiler-core[telemetry]==0.25.0->titiler-application==0.25.0->titiler->leafmap[raster]) (0.63b1)
# Requirement already satisfied: opentelemetry-instrumentation-asgi==0.63b1 in /usr/local/lib/python3.12/dist-packages (from opentelemetry-instrumentation-fastapi->titiler-core[telemetry]==0.25.0->titiler-application==0.25.0->titiler->leafmap[raster]) (0.63b1)
# Requirement already satisfied: opentelemetry-instrumentation==0.63b1 in /usr/local/lib/python3.12/dist-packages (from opentelemetry-instrumentation-fastapi->titiler-core[telemetry]==0.25.0->titiler-application==0.25.0->titiler->leafmap[raster]) (0.63b1)
# Requirement already satisfied: opentelemetry-util-http==0.63b1 in /usr/local/lib/python3.12/dist-packages (from opentelemetry-instrumentation-fastapi->titiler-core[telemetry]==0.25.0->titiler-application==0.25.0->titiler->leafmap[raster]) (0.63b1)
# Requirement already satisfied: asgiref~=3.0 in /usr/local/lib/python3.12/dist-packages (from opentelemetry-instrumentation-asgi==0.63b1->opentelemetry-instrumentation-fastapi->titiler-core[telemetry]==0.25.0->titiler-application==0.25.0->titiler->leafmap[raster]) (3.11.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server>=1.24.0->jupyter-server-proxy->leafmap[raster]) (3.0)
# Requirement already satisfied: lark>=1.2.2 in /usr/local/lib/python3.12/dist-packages (from rfc3987-syntax>=1.1.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server>=1.24.0->jupyter-server-proxy->leafmap[raster]) (1.3.1)
# Requirement already satisfied: arrow>=0.15.0 in /usr/local/lib/python3.12/dist-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server>=1.24.0->jupyter-server-proxy->leafmap[raster]) (1.4.0)

# %% [markdown]
# ## Import libraries

# %%
import os
import leafmap

# %% [markdown]
# ## Create interactive maps
#
# Specify the map center, zoom level, and height.

# %%
m = leafmap.Map(center=[40, -100], zoom=4, height="600px")
m

# %% [markdown]
# ## Add basemaps
#
# Add OpenTopoMap, USGS 3DEP Elevation, and USGS Hydrography basemaps.

# %%
m = leafmap.Map()
m.add_basemap("OpenTopoMap")
m.add_basemap("USGS 3DEP Elevation")
m.add_basemap("USGS Hydrography")
m

# %% [markdown]
# Add NLCD land cover map and legend.

# %%
m = leafmap.Map(center=[40, -100], zoom=4)
m.add_basemap("HYBRID")
m.add_basemap("NLCD 2019 CONUS Land Cover")
m.add_legend(builtin_legend="NLCD", title="NLCD Land Cover Type")
m

# %% [markdown]
# Add WMS layers.

# %%
m = leafmap.Map(center=[40, -100], zoom=4)
m.add_basemap("Esri.WorldImagery")
url = "https://www.mrlc.gov/geoserver/mrlc_display/NLCD_2019_Land_Cover_L48/wms?"
m.add_wms_layer(
    url,
    layers="NLCD_2019_Land_Cover_L48",
    name="NLCD 2019 CONUS Land Cover",
    format="image/png",
    transparent=True,
)
m.add_legend(builtin_legend="NLCD", title="NLCD Land Cover Type")
m

# %% [markdown]
# ## Get watershed data
#
# Let's download watershed data for the Calapooia River basin in Oregon.

# %%
gdf = leafmap.get_nhd_basins(feature_ids=23763529, fsource="comid", simplified=False)

# %% [markdown]
# Plot the watershed boundary on the map.

# %%
m = leafmap.Map()
m.add_gdf(gdf, layer_name="Catchment", info_mode=None)
m

# %% [markdown]
# Save the watershed boundary to a GeoJSON or shapefile.

# %%
gdf.to_file("basin.geojson", driver="GeoJSON")

# %%
gdf.to_file("basin.shp")

# %% [markdown]
# ## Download DEM
#
# Download a digital elevation model (DEM) for the watershed from the USGS 3DEP Elevation service. Convert the DEM to a Cloud Optimized GeoTIFF (COG).

# %%
leafmap.get_3dep_dem(
    gdf, resolution=30, output="dem.tif", dst_crs="EPSG:3857", to_cog=True
)

# %% [markdown]
# Display the DEM on the map.

# %%
m.add_raster("dem.tif", palette="terrain", layer_name="DEM")
m

# %% [markdown]
# ## Get DEM metadata

# %%
metadata = leafmap.image_metadata("dem.tif")
metadata

# %% [markdown]
# Get a summary statistics of the DEM.

# %%
metadata["bands"]

# %% [markdown]
# ## Add colorbar

# %%
m.add_colormap(cmap="terrain", vmin="60", vmax=1500, label="Elevation (m)")
m

# %% [markdown]
# ## Initialize WhiteboxTools
#
# Initialize the WhiteboxTools class.

# %%
wbt = leafmap.WhiteboxTools()

# %% [markdown]
# Check the WhiteboxTools version.

# %%
wbt.version()

# %% [markdown]
# Display the WhiteboxTools interface.

# %%
leafmap.whiteboxgui()

# %% [markdown]
# ## Set working directory

# %%
wbt.set_working_dir(os.getcwd())
wbt.verbose = False

# %% [markdown]
# ## Smooth DEM
#
# All WhiteboxTools functions will return 0 if they are successful, and 1 if they are not.

# %%
wbt.feature_preserving_smoothing("dem.tif", "smoothed.tif", filter=9)

# %% [markdown]
# Display the smoothed DEM and watershed boundary on the map.

# %%
m = leafmap.Map()
m.add_raster("smoothed.tif", palette="terrain", layer_name="Smoothed DEM")
m.add_geojson("basin.geojson", layer_name="Watershed", info_mode=None)
m

# %% [markdown]
# ## Create hillshade

# %%
wbt.hillshade("smoothed.tif", "hillshade.tif", azimuth=315, altitude=35)

# %% [markdown]
# Overlay the hillshade on the smoothed DEM with transparency.

# %%
m.add_raster("hillshade.tif", layer_name="Hillshade")
m.layers[-1].opacity = 0.6

# %% [markdown]
# ## Find no-flow cells
#
# Find cells with undefined flow, i.e. no valid flow direction, based on the D8 flow direction algorithm

# %%
wbt.find_no_flow_cells("smoothed.tif", "noflow.tif")

# %% [markdown]
# Display the no-flow cells on the map.

# %%
m.add_raster("noflow.tif", layer_name="No Flow Cells")
m

# %% [markdown]
# ## Fill depressions

# %%
wbt.fill_depressions("smoothed.tif", "filled.tif")

# %% [markdown]
# Alternatively, you can use depression breaching to fill the depressions.

# %%
wbt.breach_depressions("smoothed.tif", "breached.tif")

# %%
wbt.find_no_flow_cells("breached.tif", "noflow2.tif")

# %%
m.add_raster("noflow2.tif", layer_name="No Flow Cells after Breaching")
m

# %% [markdown]
# ## Delineate flow direction

# %%
wbt.d8_pointer("breached.tif", "flow_direction.tif")

# %% [markdown]
# ## Calculate flow accumulation

# %%
wbt.d8_flow_accumulation("breached.tif", "flow_accum.tif")

# %%
m.add_raster("flow_accum.tif", layer_name="Flow Accumulation")
m

# %% [markdown]
# ## Extract streams

# %%
wbt.extract_streams("flow_accum.tif", "streams.tif", threshold=5000)

# %%
m.add_raster("streams.tif", layer_name="Streams")

# %% [markdown]
# ## Calculate distance to outlet

# %%
wbt.distance_to_outlet(
    "flow_direction.tif", streams="streams.tif", output="distance_to_outlet.tif"
)

# %%
m.add_raster("distance_to_outlet.tif", layer_name="Distance to Outlet")

# %% [markdown]
# ## Vectorize streams

# %%
wbt.raster_streams_to_vector(
    "streams.tif", d8_pntr="flow_direction.tif", output="streams.shp"
)

# %% [markdown]
# The raster_streams_to_vector tool has a bug. The output vector file is missing the coordinate system. Use leafmap.vector_set_crs() to set the coordinate system.

# %%
leafmap.vector_set_crs(source="streams.shp", output="streams.shp", crs="EPSG:3857")

# %%
m.add_shp(
    "streams.shp", layer_name="Streams Vector", style={"color": "#ff0000", "weight": 3}
)
m

# %% [markdown]
# ## Delineate basins

# %%
wbt.basins("flow_direction.tif", "basins.tif")

# %%
m.add_raster("basins.tif", layer_name="Basins")

# %% [markdown]
# ## Delineate the longest flow path

# %%
wbt.longest_flowpath(
    dem="breached.tif", basins="basins.tif", output="longest_flowpath.shp"
)

# %% [markdown]
# Select only the longest flow path.

# %%
leafmap.select_largest(
    "longest_flowpath.shp", column="LENGTH", output="longest_flowpath.shp"
)

# %%
m.add_shp(
    "longest_flowpath.shp",
    layer_name="Longest Flowpath",
    style={"color": "#ff0000", "weight": 3},
)
m

# %% [markdown]
# ## Generate a pour point

# %%
if m.user_roi is not None:
    m.save_draw_features("pour_point.shp", crs="EPSG:3857")
else:
    coords = [-122.613559, 44.284383]
    leafmap.coords_to_vector(coords, output="pour_point.shp", crs="EPSG:3857")

# %% [markdown]
# ## Snap pour point to stream

# %%
wbt.snap_pour_points(
    "pour_point.shp", "flow_accum.tif", "pour_point_snapped.shp", snap_dist=300
)

# %%
m.add_shp("pour_point_snapped.shp", layer_name="Pour Point")

# %% [markdown]
# ## Delineate watershed

# %%
wbt.watershed("flow_direction.tif", "pour_point_snapped.shp", "watershed.tif")

# %%
m.add_raster("watershed.tif", layer_name="Watershed")
m

# %% [markdown]
# ## Convert watershed raster to vector

# %%
wbt.raster_to_vector_polygons("watershed.tif", "watershed.shp")

# %%
m.add_shp(
    "watershed.shp",
    layer_name="Watershed Vector",
    style={"color": "#ffff00", "weight": 3},
)
